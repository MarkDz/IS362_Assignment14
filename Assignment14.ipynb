# %% [markdown]
# # IS 362 - Assignment 14
# ## Recommender System
# ### YouTube

# %% [markdown]
# Assignment Tasks:
# - Perform a Scenario Design analysis as described below. Consider whether it makes sense for your selected recommender system to perform scenario design twice, once for the organization (e.g. Amazon.com) and once for the organization's customers.
# - Attempt to reverse engineer what you can about the site, from the site interface and any available information that you can find on the Internet or elsewhere.
# - Include specific recommendations about how to improve the site's recommendation capabilities going forward.

# %% [markdown]
# When using recommendation systems, one must be able to answer a Scenario Design Analysis with the following questions:
# - Who are your target users?
# - What are their key goals?
# - How can you help them accomplish their goals?

# %% [markdown]
# A Recommender System predicts the likelihood that a user would prefer an item. Based on previous user interaction with the data source that the system takes the information from (besides the data from other users, or historical trends), the system is capable of recommending an item to a user.

# %%
from IPython.display import Image
Image("RS_YouTube.jpeg", width=500, height=600)

# %% [markdown]
# ### Who are your target Users?
# Target users are anyone who watches videos on youtube or even uploads content for others to view.

# %% [markdown]
# ### What are their key goals?
# The key goal is that the user spend more and more time on the website and watch videos because google’s revenue is from ads and the user will watch ads only when they are watching videos.

# %% [markdown]
# ### How can you help them accomplish those goals?
#  If the recommender system recommends the videos which interest the end user, then they will stay on the website for a long time and will consume more ads.

# %%
Image("RS_Enter.jpeg", width=500, height=600)

# %%
Image("RS_Watched.jpeg", width=500, height=600)

# %%
Image("RS_After.jpeg", width=500, height=600)

# %% [markdown]
# ### Reverse Engineering
# The YouTube’s Recommendation System is driven by the Google Brain deep learning artificial intelligence project and is comprised of two neural networks. The first collects and collates information on users’ watch history and uses collaborative filtering to select hundreds of videos. This process, known as candidate generation, uses feedback from users to train the model. The second neural network ranks the selected videos in order to make recommendations to users.
# YouTube recommendations are the implicit feedback of video watches by users to train the model. Explicit feedback such as a thumbs up or a thumbs down of a video are in general rare compared to implicit and this is an even bigger issue with long-tail videos that are not popular. To accelerate training of the model for newly uploaded videos, the age of each training example is fed in as a feature. Another key aspect for discovering and surfacing new content is to use all YouTube videos watched, even on partner sites, for training of the algorithm. This way collaborative filtering can pick up viral videos right away. Finally, by adding more features and depth like searches and age of video other than the actual watches, YouTube was able to improve offline holdout precision results. YouTube’s recommendation system is one of the most sophisticated and heavily used recommendation systems in industry. According to YouTube after implementation of the RS for more than a year, it has been successful in terms of their stated goals, with recommendations accounting for around 60 percent of video clicks from the homepage.
